# %%
import pandas as pd

# %%
data = pd.read_csv('data_2017.csv')
data.head()
# Out:
#    Unnamed: 0 Symbol         Company Person Code Director Salutation  \
# 0           0   ALBK  ALLAHABAD BANK   P00064380                 MR.
# 1           1   ALBK  ALLAHABAD BANK   P00065774            DR.(MR.)
# 2           2   ALBK  ALLAHABAD BANK   P00065270                 MR.
# 3           3   ALBK  ALLAHABAD BANK   P00042037                 MR.
# 4           4   ALBK  ALLAHABAD BANK   P00065272                 MR.
#
#   Director First Name Director Middle Name Director Surname Date of Birth  \
# 0                  K.                   K.          AGARWAL   02-JUL-1949
# 1             SHAKEEL             UZ-ZAMAN           ANSARI   23-DEC-1958
# 2              NIRMAL                KUMAR             BARI   10-OCT-1961
# 3              MAHESH                   N.            BHATT   20-SEP-1948
# 4         BISWABANDHU                  NaN     BHATTACHARYA   30-NOV-1947
#
#    Gender  ... Other Directorship 11 Other Directorship 12  \
# ...

# %%
data['Age'] = data['Age']-2

# %%
data['Tenure'] = data['Tenure']-2

# %%
data['Age']
# Out:
# 0       68
# 1       59
# 2       56
# 3       69
# 4       70
#         ..
# 1501    57
# 1502    71
# 1503    -2
# 1504    71
# 1505    56
# Name: Age, Length: 1506, dtype: int64

# %%
data[data['Age'] < 0 ]['Age']
# Out:
# 51     -2
# 89     -2
# 105    -2
# 106    -2
# 109    -2
#        ..
# 1487   -2
# 1488   -2
# 1489   -2
# 1500   -2
# 1503   -2
# Name: Age, Length: 243, dtype: int64

# %%
data[data['Tenure'] < 0 ]['Tenure']
# Out:
# Series([], Name: Tenure, dtype: int64)

# %%
data['Age'] = data['Age'].replace(-2,"")

# %%
data['Age']
# Out:
# 0       68
# 1       59
# 2       56
# 3       69
# 4       70
#         ..
# 1501    57
# 1502    71
# 1503
# 1504    71
# 1505    56
# Name: Age, Length: 1506, dtype: object

# %%
data
# Out:
#       Unnamed: 0   Symbol         Company Person Code Director Salutation  \
# 0              0     ALBK  ALLAHABAD BANK   P00064380                 MR.
# 1              1     ALBK  ALLAHABAD BANK   P00065774            DR.(MR.)
# 2              2     ALBK  ALLAHABAD BANK   P00065270                 MR.
# 3              3     ALBK  ALLAHABAD BANK   P00042037                 MR.
# 4              4     ALBK  ALLAHABAD BANK   P00065272                 MR.
# ...          ...      ...             ...         ...                 ...
# 1501        1501  YESBANK   YES BANK LTD.   P00038492                 MR.
# 1502        1502  YESBANK   YES BANK LTD.   P00038046                 MS.
# 1503        1503  YESBANK   YES BANK LTD.   P00010311                 MR.
# 1504        1504  YESBANK   YES BANK LTD.   P00022630                 MR.
# 1505        1505  YESBANK   YES BANK LTD.   P00003583                 MR.
#
#      Director First Name Director Middle Name Director Surname Date of Birth  \
# ...

# %%
data.to_csv('new_data_2017.csv', encoding='utf-8', index=False)
